# %%
def load_private_key_from_file(file_path):
    with open(file_path, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None,  # or provide a password if your key is encrypted
            backend=default_backend()
        )
    return private_key



KALSHI_API_KEY = "C:\\Users\\seani\\Downloads\\kalshi_keyID.txt" # change these to be your personal credentials
private_key = load_private_key_from_file('kalshi_RSA_privateKey.txt')
KALSHI_BASE = "https://api.elections.kalshi.com/trade-api/v2"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 13
#       8     return private_key
#      12 KALSHI_API_KEY = "C:\\Users\\seani\\Downloads\\kalshi_keyID.txt" # change these to be your personal credentials
# ---> 13 private_key = load_private_key_from_file('kalshi_RSA_privateKey.txt')
#      14 KALSHI_BASE = "https://api.elections.kalshi.com/trade-api/v2"
#
# Cell In[5], line 2, in load_private_key_from_file(file_path)
#       1 def load_private_key_from_file(file_path):
# ----> 2     with open(file_path, "rb") as key_file:
#       3         private_key = serialization.load_pem_private_key(
#       4             key_file.read(),
#       5             password=None,  # or provide a password if your key is encrypted
#       6             backend=default_backend()
#       7         )
#       8     return private_key
#
# ...

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from tqdm import tqdm
import json

headers = {}
if KALSHI_API_KEY:
    headers['Authorization': KALSHI_API_KEY}

def kalshi_get(endpoint, params=None):
    url = f"https://demo-api.kalshi.co/trade-api/v2/{endpoint}"
    r = requests.get(url, headers=headers, params=params)
    r.raise_for_status()
    return r.json()
